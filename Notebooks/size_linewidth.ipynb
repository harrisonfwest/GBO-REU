# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl
from astropy.io import fits
from astropy.table import Table
import seaborn as sns
from astropy.io import ascii

import csv

mpl.rcParams['xtick.direction'] = 'in'
mpl.rcParams['ytick.direction'] = 'in'

FWHM_const = 2 * np.sqrt(2 * np.log(2))

convert = 1 # Conversion factor derived from comparing (crossmatching) ClumpFind outputs from RAMPS with RAMPS catalog

# %%
hdul = fits.open("/home/scratch/hfwest/Pilot/Results_ClumpFind/Pilot_cat.FIT")
pilot_table = Table(hdul[1].data)
pilot_table['Size1'] *= convert
pilot_table['Size2'] *= convert
pilot_table
# Out:
# <Table length=261>
# PIDENT  Peak1   Peak2  ...        Sum                 Peak         Volume
# int32  float64 float64 ...      float64             float64       float64
# ------ ------- ------- ... ------------------ ------------------- -------
#      1     5.5    49.5 ... 23.823580389719773  1.9924327868930036   105.0
#      2   178.5    59.5 ...  974.8668894991031  1.6176305723032434  2122.0
#      3     5.5    67.5 ... 127.31449153195702  1.5285319010174343  1017.0
#      4    81.5    81.5 ... 2715.2826812017674  1.5137749714504212  8736.0
#      5     6.5    19.5 ... 22.373517983714283  1.4292264006456121    64.0
#      6   164.5    49.5 ...  1167.030287139429  1.4119234086414716  2167.0
#      7     5.5    80.5 ...  57.00364032442307  1.4103681997414577   336.0
#      8   116.5    40.5 ... 1812.5130266943718  1.3553769175248795  8236.0
#      9     5.5    82.5 ... 52.493766688923664   1.352951714112742   309.0
#    ...     ...     ... ...                ...                 ...     ...
#    252   149.5    82.5 ...  3.676555887125003  0.1242760210394237    51.0
#    253   184.5    47.5 ...  3.516443433966279 0.12187572224041861    52.0
#    254   188.5    37.5 ...  3.819114492970811 0.11597561446460314    56.0
#    255   184.5    46.5 ...  4.068463385420911  0.1125263646259793    61.0
#    256   159.5    79.5 ... 4.1527429619728675 0.11024255239282979    59.0
#    257    63.5    35.5 ... 3.6285533073419427 0.10132356457584332    58.0
#    258    82.5   107.5 ... 3.3872764599260465 0.09752349544096751    58.0
#    259    28.5    34.5 ...  3.156122823192757  0.0942584047408762    52.0
#    260    73.5    30.5 ... 3.3475646610469907 0.09374111698293677    61.0
#    261    33.5    81.5 ... 2.8218243748853773 0.06228640010097476    60.0

# %%
ramps_table = ascii.read('/users/hfwest/GBO-REU/Data/RAMPS_cleaned.csv')
ramps_table
# Out:
# <Table length=2680>
#    l       b     Linear Size (pc)   sigma (km/s)
# float64 float64      float64          float64
# ------- ------- ------------------ --------------
#   9.612   0.142 2.3864112030245943 0.314694522311
#   9.623   0.191 5.3133799197117835  0.83105567403
#   9.629   0.266 1.1929340623080675 0.333130734574
#   9.634   0.298 0.7400928202292074 0.224414712996
#   9.649  -0.017 1.8243493536347024 0.319746510224
#   9.662   0.264  2.586392766502899 0.330921630441
#    9.69  -0.003  1.487332862537587 0.428652790448
#   9.698  -0.111 5.5215555638074925 0.650161586359
#   9.701  -0.224  3.832945962848816 0.549691520273
#     ...     ...                ...            ...
#  45.458  -0.089  2.561280528755118  0.51425194259
#  45.464   0.046 10.805874870442961  1.10788480868
#  45.472  -0.101  1.371327261943778 0.317604812009
#  45.475   0.001  2.272730025177551 0.891926870543
#  45.496   0.224 2.3447698529717056 0.572817750857
#  47.044   0.248  4.915135712914221 0.861155851189
#  47.141   0.319 2.0979798604316247 0.420704288902
#  47.171   0.313 3.6241963599254086 0.764417439979
#  47.223   0.318 1.2378200376099342 0.633378861293
#  47.273   0.345 3.0251869873831745 0.613219368272
